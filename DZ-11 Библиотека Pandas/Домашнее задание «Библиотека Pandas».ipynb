# %% [markdown]
# # Домашнее задание «Библиотека Pandas»

# %% [markdown]
# ### Задание 1
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера.
# Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd
import sys

# %%
sys.path.append('C:\\Users\\fosty\\Documents\\python\\Home Work\\DZ-11 Библиотека Pandas\\ml-20m')

# %%
ratings = pd.read_csv('ratings.csv')

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
ratings.query('rating == 5.0').groupby('movieId').count().sort_values('rating', ascending=False).head(1)
# Out:
#          userId  rating  timestamp
# movieId
# 318       31896   31896      31896

# %% [markdown]
# ### Задание 2
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
power = pd.read_csv('power.csv')

# %%
 power_filter = power[ ((power['country']  == 'Latvia') | (power['country']  == 'Lithuania') | (power['country']  == 'Lithuania')) & 
       ((power['category'] == 4) | (power['category'] == 12) | (power['category'] == 21)) &
      ((power['year'] >= 2005) &  (power['year'] <= 2010)) & 
                     ((power['quantity'] >=0))]

# %%
power_filter['quantity'].sum()
# Out:
# 177140.0

# %% [markdown]
# Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
pd.read_html('https://news.google.com/covid19/map?hl=ru&gl=RU&ceid=RU%3Aru', encoding = 'utf8')[0].head(50)
# Out:
#                    Местоположение Все случаи заболевания  \
# 0                        Весь мир             55 624 562
# 1       Соединенные Штаты Америки             12 172 069
# 2                           Индия              9 095 806
# 3                        Бразилия              6 052 786
# 4                         Франция              2 127 672
# 5                          Россия              2 047 563
# 6                         Испания              1 556 730
# 7                  Великобритания              1 493 383
# 8                          Италия              1 380 531
# 9                       Аргентина              1 366 182
# 10                       Колумбия              1 240 493
# 11                        Мексика              1 025 969
# 12                           Перу                948 081
# 13                       Германия                927 990
# 14                         Польша                843 475
# ...

# %%
pd.read_html('https://www.finanz.ru/valyuty/v-realnom-vremeni' , encoding = 'utf8')[0].head(50)
# Out:
#      0       1      2        3       4      5        6       7      8   \
# 0  ММВБ   3 051   0,2%   Nasdaq  11 855  -0,4%  Биткойн  18 514  -0,9%
# 1   РТС   1 263   0,3%   S&P500   3 558  -0,7%    Нефть     452   2,4%
# 2   Dow  29 263  -0,8%  FTSE100   6 351   0,3%   Золото   1 870   0,0%
#
#         9       10     11
# 0  USD/RUB  762370   0,0%
# 1  EUR/RUB  903115  -0,2%
# 2  EUR/USD   11857   0,0%

# %%
# ?pd.read_html
