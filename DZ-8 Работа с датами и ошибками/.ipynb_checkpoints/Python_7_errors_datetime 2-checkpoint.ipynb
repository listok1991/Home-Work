# %% [markdown]
# # Задача про интервалы
# Имеется список отсортированных по возрастанию целых чисел data. А также целое число n, которое лежит между минимальным и максимальным значениями из списка data. Вам необходимо определить минимальное ближайшее число к n из списка data.
#
# Пример:
# ```python
# data = [1, 7, 17, 23, 27, 35, 65]
# n = 20
# ```
#
# Ответ: 17

# %%
data = [1, 7, 17, 23, 27, 35, 65]
n = 20

# %%
for i, num in enumerate(data[:-1]):
    # print(i, data[i], data[i+1])
    
    if data[i] <= n < data[i+1]:
        print(data[i])
        break
# Out:
# 17

# %% [markdown]
# # Бинарный поиск
# Поиск по телефонному справочнику --> O(log N)

# %% [markdown]
# Рассмотрите ситуацию, в которой при фиксированном списке data вам необходимо классифицировать большое количество пользователей с разными значениями n. Например, вам необходимо классифицировать базу из 100 миллионов человек по возрастам по словарю ages:
# ```python
# ages = {
#     1: 'дети',
#     7: 'школьники',
#     17: 'студенты',
#     23: 'аспиранты',
#     27: 'молодые ученые',
#     35: 'преподаватели',
#     65: 'пенсионеры',
# }
# ```

# %%
{
    1: 'дети',
    2: 'дети',
    # ...
    6: 'дети',
    7: 'студенты',
    # ...
    16: 'студенты',
}

# %%
data = [1, 7, 17, 23, 27, 35, 65]

# %%
ages = {
    1: 'дети',
    7: 'школьники',
    17: 'студенты',
    23: 'аспиранты',
    27: 'молодые ученые',
    35: 'преподаватели',
    65: 'пенсионеры',
}

# %%
classification = {}

for age in range(1, 101):
    for i, num in enumerate(data[:-1]):
        # print(data[i], data[i+1])

        if data[i] <= age < data[i+1]:
            classification[age] = ages[data[i]]
            break
        classification[age] = 'пенсионеры'
        
            
classification
# Out:
# {1: 'дети',
#  2: 'дети',
#  3: 'дети',
#  4: 'дети',
#  5: 'дети',
#  6: 'дети',
#  7: 'школьники',
#  8: 'школьники',
#  9: 'школьники',
#  10: 'школьники',
#  11: 'школьники',
#  12: 'школьники',
#  13: 'школьники',
#  14: 'школьники',
#  15: 'школьники',
#  16: 'школьники',
#  17: 'студенты',
#  18: 'студенты',
#  19: 'студенты',
#  20: 'студенты',
#  21: 'студенты',
#  22: 'студенты',
#  23: 'аспиранты',
#  24: 'аспиранты',
#  25: 'аспиранты',
#  26: 'аспиранты',
#  27: 'молодые ученые',
#  28: 'молодые ученые',
#  29: 'молодые ученые',
#  30: 'молодые ученые',
#  31: 'молодые ученые',
#  32: 'молодые ученые',
#  33: 'молодые ученые',
#  34: 'молодые ученые',
#  35: 'преподаватели',
#  36: 'преподаватели',
#  37: 'преподаватели',
#  38: 'преподаватели',
#  39: 'преподаватели',
#  40: 'преподаватели',
#  41: 'преподаватели',
#  42: 'преподаватели',
#  43: 'преподаватели',
#  44: 'преподаватели',
#  45: 'преподаватели',
#  46: 'преподаватели',
#  47: 'преподаватели',
#  48: 'преподаватели',
#  49: 'преподаватели',
#  50: 'преподаватели',
#  51: 'преподаватели',
#  52: 'преподаватели',
#  53: 'преподаватели',
#  54: 'преподаватели',
#  55: 'преподаватели',
#  56: 'преподаватели',
#  57: 'преподаватели',
#  58: 'преподаватели',
#  59: 'преподаватели',
#  60: 'преподаватели',
#  61: 'преподаватели',
#  62: 'преподаватели',
#  63: 'преподаватели',
#  64: 'преподаватели',
#  65: 'пенсионеры',
#  66: 'пенсионеры',
#  67: 'пенсионеры',
#  68: 'пенсионеры',
#  69: 'пенсионеры',
#  70: 'пенсионеры',
#  71: 'пенсионеры',
#  72: 'пенсионеры',
#  73: 'пенсионеры',
#  74: 'пенсионеры',
#  75: 'пенсионеры',
#  76: 'пенсионеры',
#  77: 'пенсионеры',
#  78: 'пенсионеры',
#  79: 'пенсионеры',
#  80: 'пенсионеры',
#  81: 'пенсионеры',
#  82: 'пенсионеры',
#  83: 'пенсионеры',
#  84: 'пенсионеры',
#  85: 'пенсионеры',
#  86: 'пенсионеры',
#  87: 'пенсионеры',
#  88: 'пенсионеры',
#  89: 'пенсионеры',
#  90: 'пенсионеры',
#  91: 'пенсионеры',
#  92: 'пенсионеры',
#  93: 'пенсионеры',
#  94: 'пенсионеры',
#  95: 'пенсионеры',
#  96: 'пенсионеры',
#  97: 'пенсионеры',
#  98: 'пенсионеры',
#  99: 'пенсионеры',
#  100: 'пенсионеры'}

# %%
data = [1, 7, 17, 23, 27, 35, 65]

for i in data:
    print(i, classification[i])
# Out:
# 1 дети
# 7 школьники
# 17 студенты
# 23 аспиранты
# 27 молодые ученые
# 35 преподаватели
# 65 пенсионеры

# %% [markdown]
# # Обработка ошибок
# 1. Текст ошибки указывается в последней строчке
# 2. Все что перед ней - место, где ошибка произошла
# 3. Есть встроенные типы ошибок, но можно создавать и свои

# %% [markdown]
# Некоторые типы ошибок из документации (точнее [перевода](https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html)):
# - ZeroDivisionError - деление на ноль
# - ImportError - не удалось импортирование модуля или его атрибута (надо установить эту библиотеку)
# - IndexError - индекс не входит в диапазон элементов.
# - KeyError - несуществующий ключ (в словаре, множестве или другом объекте)
# - MemoryError - недостаточно памяти
# - SyntaxError - синтаксическая ошибка (вы опечатались или не закрыли скобку)
# - TypeError - операция применена к объекту несоответствующего типа
# - ValueError - функция получает аргумент правильного типа, но некорректного значения
# - Warning - предупреждение (текст на красном фоне в юпитере это предупреждение, а не ошибка)

# %%
# эту строку можно перевести в число
some_num = '123'

# %%
float(some_num)

# %%
# а эту уже нет (по крайней мере в десятичном счислении)
ups = '123a'

# %%
# ValueError - тип ошибки, далее пояснение что произошло
# ----> 1 float(ups) - в каком месте кода произошла ошибка
float(ups)

# %% [markdown]
# Пример ошибки внутри функции

# %%
def square_sum(*args):
    total_sum = 0
    for arg in args:
        total_sum += arg**2
    
    return total_sum

# %%
square_sum(1, 2, 3)
# Out:
# 14

# %%
# пытаемся применить к операцию возведения в квадрат к строке
# ----> 1 square_sum(1, 2, '3') - в какой функции произошла ошибка
# ----> 4         total_sum += arg**2 - в какой именно строке произошла ошибка

square_sum(1, 2, '3')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-7189647907b6> in <module>
#       3 # ----> 4         total_sum += arg**2 - в какой именно строке произошла ошибка
#       4
# ----> 5 square_sum(1, 2, '3')
#
# <ipython-input-17-45a18875b039> in square_sum(*args)
#       2     total_sum = 0
#       3     for arg in args:
# ----> 4         total_sum += arg**2
#       5
#       6     return total_sum
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %% [markdown]
# ## Как сделать, чтобы цикл с расчетом не падал каждый раз

# %%
try:
    # ваш код, где может произойти ошибка
    float('123a')

except:
    # код, который выполняется в случае ошибки

# %%
data = ['90', '60', '90', '240tot']
total_sum = 0

for num in data:
    try:
        total_sum += float(num)

    except:
        print('Ошибка в данных: {}'.format(num))
    
print('Итого', total_sum)

# %% [markdown]
# Как сохранить всю информацию об ошибке?

# %%
# полная версия traceback
import traceback

try:
    float('123fff')

except Exception:
    print(traceback.print_exc())
    
print('Проехали')

# %% [markdown]
# ### Блок finally

# %%
try:
    print(stats["wednesday"])
    
except IndexError:
    print("Ошибка индекса")
    
except KeyError:
    print("Ошибка ключа")
    print(1/0)
    
finally:
    print('Эта строчка будет выполнена всегда')

# %% [markdown]
# ### Более жизненный пример

# %%
from datetime import datetime

# %%
with open('real_data.txt', 'r') as f:
    for line in f:
        print(line.strip())
# Out:
# 05.10.16 23:18	1010	20,2
# 09.10.2016T 21:40:00	1036	15,6
# 05.10.16 3:23	1041
# 05.10.16 23:19	1041
# 01.10.16 4:57	1042	14,8
# 01.10.16 23:29	1042	14,4
# 03.10.16 20:20	1042	14
# 04.10.16 0:35	1042	20
# 04.10.16 13:46	1042	16,2
# 04.10.16 17:34	1042	11
# 05.10.16 15:15	1042	10800000
# 06.10.16 20:45	1042	22,6
# 07.10.16 2:54	1042	22,4
# 07.10.16 5:02	1042	24,4
# 07.10.16 6:35	1042	16,6
# 08.10.2016T 16:46:00	1042	8,6
# 01.10.16 13:39	1047
# 05.10.16 21:41	1047
# 07.10.16 9:59	1052	24
# 08.10.2016T 19:36:00	1052	18,8
# 04.10.16 11:12	1057
# 09.10.2016T 2:47:00	1057
# 09.10.2016T 16:27:00	1062	11,2
# 05.10.16 4:38	1067	19
# 04.10.16 9:56	1078	23,4
# 04.10.16 14:36	1085	17
# 05.10.16 16:41	1096	20,8
# 01.10.16 11:55	1098	15,6
# 01.10.16 14:16	1100
# 02.10.16 1:39	1100
# 02.10.16 2:49	1100
# 02.10.16 13:05	1100
# 03.10.16 4:04	1100
# 03.10.16 6:58	1100
# 03.10.16 15:01	1100
# 04.10.16 23:43	1100
# 05.10.16 5:46	1100
# 06.10.16 0:31	1100
# 06.10.16 9:25	1100
# 08.10.2016T 15:15:00	1100
# 07.10.16 9:06	1105	16,2
# 01.10.16 4:30	1108	17,8
# 01.10.16 18:16	1108	18,8
# 02.10.16 2:58	1108	20000000
# 02.10.16 6:01	1108	21
# 02.10.16 20:03	1108	16,6
# 04.10.16 2:56	1108	20
# 04.10.16 6:57	1108	19,8
# 06.10.16 6:46	1108	16,8
# 09.10.2016T 8:33:00	1108	24000000
# 08.10.2016T 8:02:00	1111	12
# 05.10.16 5:25	1112	10,2
# 09.10.2016T 0:03:00	1112	24
# 06.10.16 10:09	1113	15,8
# 09.10.2016T 12:09:00	1113	22
# 05.10.16 18:00	1114	17,4
# 06.10.16 17:58	1114	14,8
# 05.10.16 23:19	1116	20
# 01.10.16 23:13	1118	11,6
# 09.10.2016T 21:14:00	1118	20
# 05.10.16 16:30	1123	16
# 06.10.16 5:27	1123	11,2
# 01.10.16 17:46	1128	12,2
# 04.10.16 5:00	1134
# 06.10.16 12:01	1134
# 01.10.16 15:58	1135
# 02.10.16 3:19	1135
# 02.10.16 19:24	1135
# 04.10.16 10:40	1135
# 06.10.16 6:06	1135
# 06.10.16 16:08	1135
# 08.10.2016T 0:31:00	1135
# 08.10.2016T 10:16:00	1135
# 08.10.2016T 23:10:00	1135
# 01.10.16 22:28	1136	21,6
# 03.10.16 23:03	1136	17,4
# 03.10.16 8:06	1140	22
# 04.10.16 10:01	1140	22
# 01.10.16 16:53	1141	16
# 05.10.16 3:31	1145	16
# 06.10.16 4:00	1145	20
# 02.10.16 8:08	1149	10
# 07.10.16 16:12	1149	21,2
# 08.10.2016T 6:55:00	1149	30,4
# 08.10.2016T 22:55:00	1149	18800000
# 09.10.2016T 4:10:00	1149	14
# 09.10.2016T 10:26:00	1149	22
# 09.10.2016T 22:22:00	1149	16
# 07.10.16 6:57	1150	12,6
# 02.10.16 12:03	1154	13,4
# 04.10.16 22:51	1154	13,6
# 04.10.16 9:28	1159	10,2
# 04.10.16 13:34	1159	17,4
# 08.10.2016T 9:43:00	1164	22,4
# 07.10.16 14:57	1167	11,4
# 07.10.16 20:25	1175	14
# 06.10.16 12:48	1181	22,4
# 07.10.16 9:54	1182	18
# 10.10.16 2:35	1182	17
# 04.10.16 13:49	1193	24800000
# 09.10.2016T 20:49:00	1193	16,6
# 01.10.16 5:12	1198	17,8
# 06.10.16 7:52	1198	9
# 06.10.16 5:15	1201	10,6
# 05.10.16 13:55	1203
# 06.10.16 5:56	1203
# 01.10.16 16:10	1207	16,6
# 02.10.16 1:24	1207	24,2
# 02.10.16 21:17	1207	20,4
# 03.10.16 16:08	1207	25,6
# 04.10.16 17:29	1207	19,8
# 05.10.16 1:39	1207	16,4
# 05.10.16 6:33	1207	16,2
# 05.10.16 18:57	1207	17
# 05.10.16 20:51	1207	16,8
# 07.10.16 8:55	1207	19,8
# 07.10.16 17:40	1207	15,6
# 08.10.2016T 23:36:00	1207	19,2
# 09.10.2016T 10:25:00	1207	23,2
# 09.10.2016T 21:04:00	1207	10,8
# 04.10.16 7:38	1208	24,4
# 09.10.2016T 14:53:00	1208	13,4
# 05.10.16 17:15	1209	12
# 03.10.16 6:16	1213	18,6
# 06.10.16 10:04	1213	16,6
# 01.10.16 16:52	1218	12200000
# 09.10.2016T 19:10:00	1218	22400000
# 02.10.16 8:42	1219	15,4
# 03.10.16 19:32	1223	17,2
# 06.10.16 22:11	1223	17600000
# 08.10.2016T 15:18:00	1224	16,4
# 01.10.16 4:41	1226
# 03.10.16 9:32	1226
# 07.10.16 18:32	1228	18,8
# 08.10.2016T 13:21:00	1228	17,6
# 03.10.16 15:47	1230	20,6
# 01.10.16 9:02	1233
# 01.10.16 10:27	1233
# 02.10.16 22:01	1236	17,4
# 05.10.16 5:27	1238	13,6
# 09.10.2016T 14:43:00	1238	17,6
# 04.10.16 22:25	1242	18,4
# 06.10.16 4:54	1243	20,4
# 06.10.16 14:28	1243	20
# 01.10.16 4:27	1246	17,8
# 02.10.16 4:27	1246
# 02.10.16 8:45	1246
# 02.10.16 16:58	1246
# 02.10.16 17:30	1246
# 02.10.16 19:46	1246
# 03.10.16 2:05	1246
# 03.10.16 2:57	1246
# 03.10.16 7:19	1246
# 03.10.16 12:15	1246
# 03.10.16 14:58	1246
# 03.10.16 19:43	1246
# 04.10.16 7:27	1246
# 04.10.16 9:08	1246
# 04.10.16 13:52	1246
# 04.10.16 16:34	1246
# 05.10.16 0:27	1246
# 05.10.16 6:36	1246
# 05.10.16 12:59	1246
# 05.10.16 16:52	1246
# 05.10.16 17:26	1246
# 06.10.16 6:48	1246
# 08.10.2016T 2:53:00	1246
# 10.10.16 0:59	1246
# 01.10.16 16:30	1248	13,2
# 01.10.16 21:06	1248	28,8
# 02.10.16 7:12	1252	22
# 04.10.16 13:51	1252	15,6
# 01.10.16 12:36	1253	13,6
# 04.10.16 17:11	1253	8,6
# 02.10.16 16:22	1258	22
# 08.10.2016T 19:34:00	1258	20
# 02.10.16 10:36	1263	12,6
# 03.10.16 6:10	1263	18
# 02.10.16 21:42	1267
# 04.10.16 9:02	1267
# 04.10.16 12:10	1267
# 04.10.16 15:40	1267
# 04.10.16 18:37	1267
# 04.10.16 21:29	1267
# 05.10.16 21:11	1267
# 05.10.16 22:09	1267
# 06.10.16 3:58	1267
# 06.10.16 11:16	1267
# 06.10.16 19:20	1267
# 07.10.16 10:18	1267
# 08.10.2016T 18:18:00	1267
# 09.10.2016T 4:41:00	1267
# 09.10.2016T 9:13:00	1267
# 09.10.2016T 15:37:00	1267
# 09.10.2016T 18:56:00	1267
# 05.10.16 2:48	1268	16,4
# 07.10.16 19:36	1268	16
# 02.10.16 14:12	1269	22
# 07.10.16 3:29	1270	21,8
# 01.10.16 8:56	1273	14,6
# 08.10.2016T 13:49:00	1273	22
# 07.10.16 6:00	1274	25
# 04.10.16 13:47	1278	15,6
# 07.10.16 6:42	1278	17,8
# 08.10.2016T 3:24:00	1279	14,8
# 03.10.16 1:03	1281	18,2
# 02.10.16 6:11	1283	12,6
# 02.10.16 19:24	1283	11,8
# 07.10.16 13:37	1288	16
# 08.10.2016T 19:46:00	1288	30,4
# 07.10.16 2:41	1291	13,4
# 01.10.16 17:29	1293	18,4
# 02.10.16 20:12	1293	20
# 02.10.16 23:36	1294	17
# 07.10.16 10:32	1296	26
# 03.10.16 20:41	1298	21
# 03.10.16 22:35	1298	19,4
# 05.10.16 12:19	1298	16
# 02.10.16 11:43	1300	12,8
# 03.10.16 23:18	1300	14
# 03.10.16 18:28	1302	21800000
# 02.10.16 8:06	1303	11,8
# 06.10.16 6:23	1303	25,8
# 03.10.16 10:42	1308	18
# 06.10.16 18:52	1308	10,2
# 06.10.16 16:16	1313	12
# 08.10.2016T 18:12:00	1313	13,8
# 02.10.16 14:04	1315	16,6
# 03.10.16 14:10	1318
# 03.10.16 18:15	1318
# 03.10.16 18:27	1318
# 04.10.16 17:09	1318
# 05.10.16 11:07	1318
# 06.10.16 1:46	1318
# 06.10.16 22:29	1318
# 07.10.16 0:44	1318
# 07.10.16 10:17	1318
# 07.10.16 11:29	1318
# 08.10.2016T 23:18:00	1318
# 09.10.2016T 1:37:00	1318
# 09.10.2016T 7:48:00	1318
# 09.10.2016T 22:27:00	1318
# 06.10.16 17:08	1320	18
# 09.10.2016T 2:35:00	1323	16
# 09.10.2016T 10:08:00	1323	28,6
# 05.10.16 7:29	1328	18,4
# 05.10.16 11:58	1328	18,8
# 03.10.16 0:36	1330	17,8
# 09.10.2016T 2:08:00	1331	16,8
# 03.10.16 2:19	1332	19,4
# 04.10.16 22:01	1333	20
# 08.10.2016T 3:48:00	1334	16
# 03.10.16 1:32	1343	22
# 08.10.2016T 4:34:00	1350	12800000
# 04.10.16 4:09	1351	20
# 06.10.16 19:09	1353	17,4
# 03.10.16 1:30	1354	15,6
# 02.10.16 23:30	1355	22
# 08.10.2016T 6:50:00	1359	14,4
# 02.10.16 13:33	1362	12,2
# 05.10.16 21:36	1363	12,2
# 04.10.16 22:06	1364	20
# 01.10.16 5:29	1366	13000000
# 07.10.16 9:40	1367	22,4
# 04.10.16 7:31	1371	13,6
# 04.10.16 1:36	1372	30,4
# 07.10.16 17:25	1374	12,4
# 05.10.16 23:06	1377	16
# 06.10.16 14:29	1380	30,4
# 09.10.2016T 4:55:00	1382	23,2
# 05.10.16 21:24	1383	20
# 05.10.16 8:14	1386	12,6
# 03.10.16 11:43	1387	14,6
# 01.10.16 6:21	1388	11,8
# 03.10.16 6:03	1392	20,2
# 06.10.16 5:34	1393	10
# 04.10.16 23:55	1394	12,8
# 05.10.16 5:01	1397	20,6
# 05.10.16 22:54	1398	18
# 01.10.16 17:01	1424
# 03.10.16 6:50	1424
# 04.10.16 5:27	1424
# 04.10.16 16:14	1424
# 04.10.16 18:21	1424
# 05.10.16 23:33	1424
# 06.10.16 7:27	1424
# 07.10.16 3:01	1424
# 07.10.16 16:08	1424
# 07.10.16 16:12	1424
# 08.10.2016T 12:41:00	1424
# 08.10.2016T 15:26:00	1424
# 08.10.2016T 17:21:00	1424
# 09.10.2016T 8:00:00	1424
# 10.10.16 1:24	1424

# %%
def to_datetime(date):
    try:
        return datetime.strptime(date, '%d.%m.%y %H:%M')
    except ValueError:
        try:
            return datetime.strptime(date, '%d.%m.%YT %H:%M:%S')
        except ValueError:
            return datetime.strptime(date, '%d.%m.%YT %H:%M:%S')

# %%
KNOWN_FORMAT = ['%d.%m.%y %H:%M', '%d.%m.%YT %H:%M:%S']

def to_datetime(date):
    for format_ in KNOWN_FORMAT:
        try:
            return datetime.strptime(date, format_)
        except:
            pass
    
    print('неизвестный формат ', date)
    return ''

# %%
wrong_line = 0

with open('real_data.txt', 'r') as f:
    for i, line in enumerate(f):
        # print(line)
        line = line.strip().split('\t')
        
        if len(line) == 3:
            date, user_id, cost = line
            date = to_datetime(date)
        else:
            wrong_line += 1
            
print('Битых строк', wrong_line)
print('Всего строка', i)
# Out:
# Битых строк 104
# Всего строка 293

# %% [markdown]
# Чем прекрасен этот файл:
# 1. Даты имеют разный формат: за 8 и 9 октября формат с "09.10.2016 21:40" сменился на "09.10.2016T 21:40:00" (добавилась буква T и секунды). Разработчики объяснили этот тем, что сбились настройки после обновления одной из баз данных.
# 2. У покупок некоторых пользователей неизвестно значение выручки, из-за чего количество столбцов в строке уменьшается на один.
# 3. У некоторых строк реальная сумма покупки умножена на миллион. Так иногда действительно делают, чтобы избежать дробных чисел и работать только с целыми.

# %% [markdown]
# Необходимо посчитать сумму выручки из третьего столбца.

# %% [markdown]
# # Работа с внешними источниками
# Алгоритм экспоненциальной задержки

# %%
import requests
import time

# %%
time.sleep(5)

# %%
for n in ...:
    try:
        requests.get()
    except:
        time.sleep(2**n)

# %%
def exchange_rates(host, timeout):
    return requests.get(f'{host}/daily_json.js', timeout=timeout).json()

# %%
N_RETRIES = 5

rates = None
for i in range(N_RETRIES):
    try:
        if i >= 4:
            rates = exchange_rates('https://www.cbr-xml-daily.ru', timeout=1)
        else:
            rates = exchange_rates('https://www.cbr-xml-daily.ru', timeout=0.001)
    except requests.Timeout as e:
        print(f'Серверу тяжело, надо подождать. Жду {2**i}с')
        time.sleep(2**i)
        
if rates:
    print(rates)
else:
    raise ValueError('Пора чинить сервер')
# Out:
# Серверу тяжело, надо подождать. Жду 1с
# Серверу тяжело, надо подождать. Жду 2с
# Серверу тяжело, надо подождать. Жду 4с
# Серверу тяжело, надо подождать. Жду 8с
# {'Date': '2020-10-03T11:30:00+03:00', 'PreviousDate': '2020-10-02T11:30:00+03:00', 'PreviousURL': '//www.cbr-xml-daily.ru/archive/2020/10/02/daily_json.js', 'Timestamp': '2020-10-02T20:00:00+03:00', 'Valute': {'AUD': {'ID': 'R01010', 'NumCode': '036', 'CharCode': 'AUD', 'Nominal': 1, 'Name': 'Австралийский доллар', 'Value': 55.8979, 'Previous': 55.5393}, 'AZN': {'ID': 'R01020A', 'NumCode': '944', 'CharCode': 'AZN', 'Nominal': 1, 'Name': 'Азербайджанский манат', 'Value': 45.9632, 'Previous': 45.484}, 'GBP': {'ID': 'R01035', 'NumCode': '826', 'CharCode': 'GBP', 'Nominal': 1, 'Name': 'Фунт стерлингов Соединенного королевства', 'Value': 101.0114, 'Previous': 99.4792}, 'AMD': {'ID': 'R01060', 'NumCode': '051', 'CharCode': 'AMD', 'Nominal': 100, 'Name': 'Армянских драмов', 'Value': 16.0024, 'Previous': 15.8355}, 'BYN': {'ID': 'R01090B', 'NumCode': '933', 'CharCode': 'BYN', 'Nominal': 1, 'Name': 'Белорусский рубль', 'Value': 29.8002, 'Previous': 29.7198}, 'BGN': {'ID': 'R01100', 'NumCode': '975', 'CharCode': 'BGN', 'Nominal': 1, 'Name': 'Болгарский лев', 'Value': 46.8174, 'Previous': 46.3655}, 'BRL': {'ID': 'R01115', 'NumCode': '986', 'CharCode': 'BRL', 'Nominal': 1, 'Name': 'Бразильский реал', 'Value': 13.8364, 'Previous': 13.7727}, 'HUF': {'ID': 'R01135', 'NumCode': '348', 'CharCode': 'HUF', 'Nominal': 100, 'Name': 'Венгерских форинтов', 'Value': 25.4876, 'Previous': 25.0697}, 'HKD': {'ID': 'R01200', 'NumCode': '344', 'CharCode': 'HKD', 'Nominal': 1, 'Name': 'Гонконгский доллар', 'Value': 10.0759, 'Previous': 99.7089}, 'DKK': {'ID': 'R01215', 'NumCode': '208', 'CharCode': 'DKK', 'Nominal': 1, 'Name': 'Датская крона', 'Value': 12.3033, 'Previous': 12.1843}, 'USD': {'ID': 'R01235', 'NumCode': '840', 'CharCode': 'USD', 'Nominal': 1, 'Name': 'Доллар США', 'Value': 78.0915, 'Previous': 77.2774}, 'EUR': {'ID': 'R01239', 'NumCode': '978', 'CharCode': 'EUR', 'Nominal': 1, 'Name': 'Евро', 'Value': 91.5779, 'Previous': 90.7237}, 'INR': {'ID': 'R01270', 'NumCode': '356', 'CharCode': 'INR', 'Nominal': 10, 'Name': 'Индийских рупий', 'Value': 10.6373, 'Previous': 10.5691}, 'KZT': {'ID': 'R01335', 'NumCode': '398', 'CharCode': 'KZT', 'Nominal': 100, 'Name': 'Казахстанских тенге', 'Value': 18.0435, 'Previous': 17.9803}, 'CAD': {'ID': 'R01350', 'NumCode': '124', 'CharCode': 'CAD', 'Nominal': 1, 'Name': 'Канадский доллар', 'Value': 58.7242, 'Previous': 58.1208}, 'KGS': {'ID': 'R01370', 'NumCode': '417', 'CharCode': 'KGS', 'Nominal': 100, 'Name': 'Киргизских сомов', 'Value': 98.2094, 'Previous': 97.049}, 'CNY': {'ID': 'R01375', 'NumCode': '156', 'CharCode': 'CNY', 'Nominal': 1, 'Name': 'Китайский юань', 'Value': 11.4996, 'Previous': 11.3797}, 'MDL': {'ID': 'R01500', 'NumCode': '498', 'CharCode': 'MDL', 'Nominal': 10, 'Name': 'Молдавских леев', 'Value': 46.208, 'Previous': 45.6048}, 'NOK': {'ID': 'R01535', 'NumCode': '578', 'CharCode': 'NOK', 'Nominal': 10, 'Name': 'Норвежских крон', 'Value': 83.9152, 'Previous': 83.3836}, 'PLN': {'ID': 'R01565', 'NumCode': '985', 'CharCode': 'PLN', 'Nominal': 1, 'Name': 'Польский злотый', 'Value': 20.3692, 'Previous': 20.0841}, 'RON': {'ID': 'R01585F', 'NumCode': '946', 'CharCode': 'RON', 'Nominal': 1, 'Name': 'Румынский лей', 'Value': 18.7851, 'Previous': 18.6085}, 'XDR': {'ID': 'R01589', 'NumCode': '960', 'CharCode': 'XDR', 'Nominal': 1, 'Name': 'СДР (специальные права заимствования)', 'Value': 110.1496, 'Previous': 108.7733}, 'SGD': {'ID': 'R01625', 'NumCode': '702', 'CharCode': 'SGD', 'Nominal': 1, 'Name': 'Сингапурский доллар', 'Value': 57.2602, 'Previous': 56.7132}, 'TJS': {'ID': 'R01670', 'NumCode': '972', 'CharCode': 'TJS', 'Nominal': 10, 'Name': 'Таджикских сомони', 'Value': 75.6701, 'Previous': 74.8449}, 'TRY': {'ID': 'R01700J', 'NumCode': '949', 'CharCode': 'TRY', 'Nominal': 1, 'Name': 'Турецкая лира', 'Value': 10.0576, 'Previous': 10.0192}, 'TMT': {'ID': 'R01710A', 'NumCode': '934', 'CharCode': 'TMT', 'Nominal': 1, 'Name': 'Новый туркменский манат', 'Value': 22.3438, 'Previous': 22.1108}, 'UZS': {'ID': 'R ...

# %%
exchange_rates('https://www.cbr-xml-daily.ru', timeout=1)
# Out:
# {'Date': '2020-10-03T11:30:00+03:00',
#  'PreviousDate': '2020-10-02T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2020/10/02/daily_json.js',
#  'Timestamp': '2020-10-02T20:00:00+03:00',
#  'Valute': {'AUD': {'ID': 'R01010',
#    'NumCode': '036',
#    'CharCode': 'AUD',
#    'Nominal': 1,
#    'Name': 'Австралийский доллар',
#    'Value': 55.8979,
#    'Previous': 55.5393},
#   'AZN': {'ID': 'R01020A',
#    'NumCode': '944',
#    'CharCode': 'AZN',
#    'Nominal': 1,
#    'Name': 'Азербайджанский манат',
#    'Value': 45.9632,
#    'Previous': 45.484},
#   'GBP': {'ID': 'R01035',
#    'NumCode': '826',
#    'CharCode': 'GBP',
#    'Nominal': 1,
#    'Name': 'Фунт стерлингов Соединенного королевства',
#    'Value': 101.0114,
#    'Previous': 99.4792},
#   'AMD': {'ID': 'R01060',
#    'NumCode': '051',
#    'CharCode': 'AMD',
#    'Nominal': 100,
#    'Name': 'Армянских драмов',
#    'Value': 16.0024,
#    'Previous': 15.8355},
#   'BYN': {'ID': 'R01090B',
#    'NumCode': '933',
#    'CharCode': 'BYN',
#    'Nominal': 1,
#    'Name': 'Белорусский рубль',
#    'Value': 29.8002,
#    'Previous': 29.7198},
#   'BGN': {'ID': 'R01100',
#    'NumCode': '975',
#    'CharCode': 'BGN',
#    'Nominal': 1,
#    'Name': 'Болгарский лев',
#    'Value': 46.8174,
#    'Previous': 46.3655},
#   'BRL': {'ID': 'R01115',
#    'NumCode': '986',
#    'CharCode': 'BRL',
#    'Nominal': 1,
#    'Name': 'Бразильский реал',
#    'Value': 13.8364,
#    'Previous': 13.7727},
#   'HUF': {'ID': 'R01135',
#    'NumCode': '348',
#    'CharCode': 'HUF',
#    'Nominal': 100,
#    'Name': 'Венгерских форинтов',
#    'Value': 25.4876,
#    'Previous': 25.0697},
#   'HKD': {'ID': 'R01200',
#    'NumCode': '344',
#    'CharCode': 'HKD',
#    'Nominal': 1,
#    'Name': 'Гонконгский доллар',
#    'Value': 10.0759,
#    'Previous': 99.7089},
#   'DKK': {'ID': 'R01215',
#    'NumCode': '208',
#    'CharCode': 'DKK',
#    'Nominal': 1,
#    'Name': 'Датская крона',
#    'Value': 12.3033,
#    'Previous': 12.1843},
#   'USD': {'ID': 'R01235',
#    'NumCode': '840',
#    'CharCode': 'USD',
#    'Nominal': 1,
#    'Name': 'Доллар США',
#    'Value': 78.0915,
#    'Previous': 77.2774},
#   'EUR': {'ID': 'R01239',
#    'NumCode': '978',
#    'CharCode': 'EUR',
#    'Nominal': 1,
#    'Name': 'Евро',
#    'Value': 91.5779,
#    'Previous': 90.7237},
#   'INR': {'ID': 'R01270',
#    'NumCode': '356',
#    'CharCode': 'INR',
#    'Nominal': 10,
#    'Name': 'Индийских рупий',
#    'Value': 10.6373,
#    'Previous': 10.5691},
#   'KZT': {'ID': 'R01335',
#    'NumCode': '398',
#    'CharCode': 'KZT',
#    'Nominal': 100,
#    'Name': 'Казахстанских тенге',
#    'Value': 18.0435,
#    'Previous': 17.9803},
#   'CAD': {'ID': 'R01350',
#    'NumCode': '124',
#    'CharCode': 'CAD',
#    'Nominal': 1,
#    'Name': 'Канадский доллар',
#    'Value': 58.7242,
#    'Previous': 58.1208},
#   'KGS': {'ID': 'R01370',
#    'NumCode': '417',
#    'CharCode': 'KGS',
#    'Nominal': 100,
#    'Name': 'Киргизских сомов',
#    'Value': 98.2094,
#    'Previous': 97.049},
#   'CNY': {'ID': 'R01375',
#    'NumCode': '156',
#    'CharCode': 'CNY',
#    'Nominal': 1,
#    'Name': 'Китайский юань',
#    'Value': 11.4996,
#    'Previous': 11.3797},
#   'MDL': {'ID': 'R01500',
#    'NumCode': '498',
#    'CharCode': 'MDL',
#    'Nominal': 10,
#    'Name': 'Молдавских леев',
#    'Value': 46.208,
#    'Previous': 45.6048},
#   'NOK': {'ID': 'R01535',
#    'NumCode': '578',
#    'CharCode': 'NOK',
#    'Nominal': 10,
#    'Name': 'Норвежских крон',
#    'Value': 83.9152,
#    'Previous': 83.3836},
#   'PLN': {'ID': 'R01565',
#    'NumCode': '985',
#    'CharCode': 'PLN',
#    'Nominal': 1,
#    'Name': 'Польский злотый',
#    'Value': 20.3692,
#    'Previous': 20.0841},
#   'RON': {'ID': 'R01585F',
#    'NumCode': '946',
#    'CharCode': 'RON',
#    'Nominal': 1,
#    'Name': 'Румынский лей',
#    'Value': 18.7851,
#    'Previous': 18.6085},
#   'XDR': {'ID': 'R01589',
#    'NumCode': '960',
#    'CharCode': 'XDR',
#    'Nominal': 1,
#    'Name': 'СДР (специальные права заимствования)',
#    'Value': 110.1496,
#    'Previous': 108.7733},
#   'SGD': {'ID': 'R01625',
#    'NumCode': '702',
#    'CharCode': 'SGD',
#    'Nominal': 1,
#    'Name': 'Сингапурский доллар',
#    'Value': 57.2602,
#    'Previous': 56.7132},
#   'TJS': {'ID': 'R01670',
#    'NumCode': '972',
#    'CharCode': 'TJS',
#    'Nominal': 10,
#    'Name': 'Таджикских сомони',
#    'Value': 75.6701,
#    'Previous': 74.8449},
#   'TRY': {'ID': 'R01700J',
#    'NumCode': '949',
#    'CharCode': 'TRY',
#    'Nominal': 1,
#    'Name': 'Турецкая лира',
#    'Value': 10.0576,
#    'Previous': 10.0192},
#   'TMT': {'ID': 'R01710A',
#    'NumCode': '934',
#    'CharCode': 'TMT',
#    'Nominal': 1,
#    'Name': 'Новый туркменский манат',
#    'Value': 22.3438,
#    'Previous': 22.1108},
#   'UZS': {'ID': 'R01717',
#    'NumCode': '860',
#    'CharCode': 'UZS',
#    'Nominal': 10000,
#    'Name': 'Узбекских сумов',
#    'Value': 76.0533,
#    'Previous': 74.8724},
#   'UAH': {'ID': 'R01720',
#    'NumCode': '980',
#    'CharCode': 'UAH',
#    'Nominal': 10,
#    'Name': 'Украинских гривен',
#    'Value': 27.5515,
#    'Previous': 27.2677},
#   'CZK': {'ID': 'R01760',
#    'NumCode': '203',
#    'CharCode': 'CZK',
#    'Nominal': 10,
#    'Name': 'Чешских крон',
#    'Value': 34.0416,
#    'Previous': 33.6398},
#   'SEK': {'ID': 'R01770',
#    'NumCode': '752',
#    'CharCode': 'SEK',
#    'Nominal': 10,
#    'Name': 'Шведских крон',
#    'Value': 87.7196,
#    'Previous': 86.4671},
#   'CHF': {'ID': 'R01775',
#    'NumCode': '756',
#    'CharCode': 'CHF',
#    'Nominal': 1,
#    'Name': 'Швейцарский франк',
#    'Value': 84.8636,
#    'Previous': 84.0154},
#   'ZAR': {'ID': 'R01810',
#    'NumCode': '710',
#    'CharCode': 'ZAR',
#    'Nominal': 10,
#    'Name': 'Южноафриканских рэндов',
#    'Value': 46.8661,
#    'Previous': 46.5743},
#   'KRW': {'ID': 'R01815',
#    'NumCode': '410',
#    'CharCode': 'KRW',
#    'Nominal': 1000,
#    'Name': 'Вон Республики Корея',
#    'Value': 67.0881,
#    'Previous': 66.4901},
#   'JPY': {'ID': 'R01820',
#    'NumCode': '392',
#    'CharCode': 'JPY',
#    'Nominal': 100,
#    'Name': 'Японских иен',
#    'Value': 74.2491,
#    'Previous': 73.2244}}}

# %% [markdown]
# # Даты

# %%
# иногда импортируют так
import datetime

# %%
# можно и так
import datetime as dt

# %%
# у нас будет вариант покороче (но это не одно и то же)
from datetime import datetime

# %%
date_string = '09.05.2018  09:00'

# %%
# сейчас date_string это просто строка
type(date_string)

# %%
datetime.strptime('09.05.2018 09:00', '%d.%m.%Y %H:%M')

# %%
# https://docs.python.org/3/library/datetime.html

date_datetime = datetime.strptime( date_string, '%d.%m.%Y %H:%M' )
date_datetime

# %%
# теперь можем работать с датами
type(date_datetime)

# %%
# получить номер года и часа
date_datetime.year, date_datetime.hour

# %%
# день недели
date_datetime.weekday()

# %%
# сегодня
datetime.now()

# %% [markdown]
# ### Упражнение
# С помощью метода datetime.strptime переведите строку 'May 25 2017 5:00AM' в формат datetime.

# %% [markdown]
# ### Прибавление интервала к датам

# %%
from datetime import timedelta

# %%
start_date = '2018-01-01'
end_date = '2018-01-07'

# %%
type(start_date)

# %%
start_date_datetime = datetime.strptime(start_date, '%Y-%m-%d')
start_date_datetime

# %%
start_date_datetime + timedelta(days=1)

# %%
start_date_datetime + timedelta(days=-7, minutes=-1)

# %% [markdown]
# ### Перевод обратно в строку

# %%
date = datetime(2018, 9, 1)
date

# %%
date.strftime('%Y-%m-%d')

# %%
date.strftime('%B %d %Y %I:%M%p')

# %%
datetime.now().strftime('%Y-%m-01')

# %%
# как получить первый день месяца

date.strftime('%Y-%m-01')

# %%
start_date = '2018-01-01'
end_date = '2018-01-07'

# %%
start_date, end_date

# %%
start_date_dt = datetime.strptime(start_date, '%Y-%m-%d')
end_date_dt = datetime.strptime(end_date, '%Y-%m-%d')

print(start_date_dt, end_date_dt)

# %%
i = 0

while i < 10:
    # ...
    i += 1
    print(i)

# %%
current_dt = start_date_dt

while current_dt <= end_date_dt:
    print(current_dt.strftime('%Y-%m-%d'))
    
    current_dt += timedelta(days=1)

# %%
current_dt = start_date_dt

while current_dt.strftime('%Y-%m-%d') <= end_date:
    print(current_dt.strftime('%Y-%m-%d'))
    
    current_dt += timedelta(days=1)

# %%
# можно и с помощью list comprehension
[(start_date_dt + timedelta(days=x)).strftime('%Y-%m-%d') for x in range(10)]

# %% [markdown]
# ### Нагрузка на систему по часам

# %%
stats = {}

with open('logs.csv', 'r') as f:
    for line in f:
        line = line.strip()
        print(line)
        
        break
        
        # вычисления нагрузки на систему...
        
# результат
stats

# %%
# а в процентном соотношении?

# %% [markdown]
# ###  Unixtime
# Количество секунд, прошедших с 1 января 1970 года по UTC

# %%
import time
from datetime import date
from datetime import datetime

# %%
d = date(2019, 3, 11)

unixtime = time.mktime(d.timetuple())
unixtime

# %%
from datetime import datetime

# %%
datetime.fromtimestamp(1552251600)

# %% [markdown]
# На практике все сложнее https://habr.com/ru/post/452584/
